# %% [markdown]
# # CI280 - Final Project - Part B
# # Data preparation, Sort, Groupby and Plot( 100 pts)
#
# ## Name: Sakina Fathima Khan
# ### Student ID: kh20830

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 8))

# %%
df = pd.read_csv('data//owid-covid-data.csv')

# %%
# limiting the display rows
pd.set_option('display.max_rows', 5)
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-01-23          NaN        0.0
# 1          AFG      Asia  Afghanistan  2020-01-24          NaN        0.0
# ...        ...       ...          ...         ...          ...        ...
# 60287      ZWE    Africa     Zimbabwe  2020-12-01      10129.0      179.0
# 60288      ZWE    Africa     Zimbabwe  2020-12-02      10129.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 60287             104.429         277.0         1.0                0.429  ...
# 60288              88.714         277.0         0.0                0.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 60287        1899.775             21.4                307.846
# 60288        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 60287                 1.82             1.6          30.7
# 60288                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 60287                  36.791                         1.7            61.49
# 60288                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# ...                        ...
# 60287                    0.535
# 60288                    0.535
#
# [60289 rows x 50 columns]

# %%
df = df[ (df['location'] != 'World') ]
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-01-23          NaN        0.0
# 1          AFG      Asia  Afghanistan  2020-01-24          NaN        0.0
# ...        ...       ...          ...         ...          ...        ...
# 60287      ZWE    Africa     Zimbabwe  2020-12-01      10129.0      179.0
# 60288      ZWE    Africa     Zimbabwe  2020-12-02      10129.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 60287             104.429         277.0         1.0                0.429  ...
# 60288              88.714         277.0         0.0                0.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 60287        1899.775             21.4                307.846
# 60288        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 60287                 1.82             1.6          30.7
# 60288                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 60287                  36.791                         1.7            61.49
# 60288                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# ...                        ...
# 60287                    0.535
# 60288                    0.535
#
# [59973 rows x 50 columns]

# %%
# Show number of records 
import random
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')
# Out:
# Sakina Fathima Khan , id: kh20830 9301
# ------------------------------

# %% [markdown]
# # C) Handing Missing Data and Ploting
# # ( 20 pts)
#
# ## use is null() vs. notnull()
# ### use dropna
# ### use replacena

# %%
# show last five rows
df.tail()
# Out:
#       iso_code continent  location        date  total_cases  new_cases  \
# 60284      ZWE    Africa  Zimbabwe  2020-11-28       9822.0      108.0
# 60285      ZWE    Africa  Zimbabwe  2020-11-29       9822.0        0.0
# 60286      ZWE    Africa  Zimbabwe  2020-11-30       9950.0      128.0
# 60287      ZWE    Africa  Zimbabwe  2020-12-01      10129.0      179.0
# 60288      ZWE    Africa  Zimbabwe  2020-12-02      10129.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 60284              92.857         275.0         0.0                1.429  ...
# 60285              86.000         275.0         0.0                1.000  ...
# 60286              91.714         276.0         1.0                0.429  ...
# 60287             104.429         277.0         1.0                0.429  ...
# 60288              88.714         277.0         0.0                0.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 60284        1899.775             21.4                307.846
# 60285        1899.775             21.4                307.846
# 60286        1899.775             21.4                307.846
# 60287        1899.775             21.4                307.846
# 60288        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 60284                 1.82             1.6          30.7
# 60285                 1.82             1.6          30.7
# 60286                 1.82             1.6          30.7
# 60287                 1.82             1.6          30.7
# 60288                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 60284                  36.791                         1.7            61.49
# 60285                  36.791                         1.7            61.49
# 60286                  36.791                         1.7            61.49
# 60287                  36.791                         1.7            61.49
# 60288                  36.791                         1.7            61.49
#
#        human_development_index
# 60284                    0.535
# 60285                    0.535
# 60286                    0.535
# 60287                    0.535
# 60288                    0.535
#
# [5 rows x 50 columns]

# %%
df.shape
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

# 1) Show the number records of miss data for continent ( 2 pts)
#    Show the the last five those records 

print('The number records missing data for continent')
print(len(df[df.continent.isnull()]))

df[df.continent.isnull()].tail()
# Out:
# Sakina Fathima Khan , id: kh20830 1750
# ------------------------------
# The number records missing data for continent
# 315
#       iso_code continent       location        date  total_cases  new_cases  \
# 24636      NaN       NaN  International  2020-11-28        721.0        0.0
# 24637      NaN       NaN  International  2020-11-29        721.0        0.0
# 24638      NaN       NaN  International  2020-11-30        721.0        0.0
# 24639      NaN       NaN  International  2020-12-01        721.0        0.0
# 24640      NaN       NaN  International  2020-12-02        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 24636                 0.0          15.0         0.0                  0.0  ...
# 24637                 0.0          15.0         0.0                  0.0  ...
# 24638                 0.0          15.0         0.0                  0.0  ...
# 24639                 0.0          15.0         0.0                  0.0  ...
# 24640                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 24636             NaN              NaN                    NaN
# 24637             NaN              NaN                    NaN
# 24638             NaN              NaN                    NaN
# 24639             NaN              NaN                    NaN
# 24640             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 24636                  NaN             NaN           NaN
# 24637                  NaN             NaN           NaN
# 24638                  NaN             NaN           NaN
# 24639                  NaN             NaN           NaN
# 24640                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 24636                     NaN                         NaN              NaN
# 24637                     NaN                         NaN              NaN
# 24638                     NaN                         NaN              NaN
# 24639                     NaN                         NaN              NaN
# 24640                     NaN                         NaN              NaN
#
#        human_development_index
# 24636                      NaN
# 24637                      NaN
# 24638                      NaN
# 24639                      NaN
# 24640                      NaN
#
# [5 rows x 50 columns]

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')


# 2-3) Show the number records of miss data for continent and iso_code (2 pts)
#    Show the the last five those records ( 2 pts)

print('The number of records missing data for continent and iso_code')
print(len(df[df.continent.isnull()& df.iso_code.isnull()]))
df[df.continent.isnull()& df.iso_code.isnull()].tail()
# Out:
# Sakina Fathima Khan , id: kh20830 1791
# ------------------------------
# The number of records missing data for continent and iso_code
# 315
#       iso_code continent       location        date  total_cases  new_cases  \
# 24636      NaN       NaN  International  2020-11-28        721.0        0.0
# 24637      NaN       NaN  International  2020-11-29        721.0        0.0
# 24638      NaN       NaN  International  2020-11-30        721.0        0.0
# 24639      NaN       NaN  International  2020-12-01        721.0        0.0
# 24640      NaN       NaN  International  2020-12-02        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 24636                 0.0          15.0         0.0                  0.0  ...
# 24637                 0.0          15.0         0.0                  0.0  ...
# 24638                 0.0          15.0         0.0                  0.0  ...
# 24639                 0.0          15.0         0.0                  0.0  ...
# 24640                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 24636             NaN              NaN                    NaN
# 24637             NaN              NaN                    NaN
# 24638             NaN              NaN                    NaN
# 24639             NaN              NaN                    NaN
# 24640             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 24636                  NaN             NaN           NaN
# 24637                  NaN             NaN           NaN
# 24638                  NaN             NaN           NaN
# 24639                  NaN             NaN           NaN
# 24640                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 24636                     NaN                         NaN              NaN
# 24637                     NaN                         NaN              NaN
# 24638                     NaN                         NaN              NaN
# 24639                     NaN                         NaN              NaN
# 24640                     NaN                         NaN              NaN
#
#        human_development_index
# 24636                      NaN
# 24637                      NaN
# 24638                      NaN
# 24639                      NaN
# 24640                      NaN
#
# [5 rows x 50 columns]

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')



# 4-5) For the records for Iraq, which columns has missing data (4 pts)
res = df[df['location']=='Iraq']
res

col_names = res.columns
col_names

print('The following columns are missing data for Iraq')

print(' Column Name \t\t\t\tMissing Data')
print('----------------------------------------------------')
for name in col_names:
    num = len( res[res[name].isnull()])
    if num > 0:
        print('{0: <40}'. format(name), num)
# Out:
# Sakina Fathima Khan , id: kh20830 6384
# ------------------------------
# The following columns are missing data for Iraq
#  Column Name 				Missing Data
# ----------------------------------------------------
# total_cases                              32
# new_cases_smoothed                       5
# total_deaths                             41
# new_deaths_smoothed                      5
# total_cases_per_million                  32
# new_cases_smoothed_per_million           5
# total_deaths_per_million                 41
# new_deaths_smoothed_per_million          5
# reproduction_rate                        63
# icu_patients                             315
# icu_patients_per_million                 315
# hosp_patients                            315
# hosp_patients_per_million                315
# weekly_icu_admissions                    315
# weekly_icu_admissions_per_million        315
# weekly_hosp_admissions                   315
# weekly_hosp_admissions_per_million       315
# total_tests                              103
# new_tests                                114
# total_tests_per_thousand                 103
# new_tests_per_thousand                   114
# new_tests_smoothed                       84
# new_tests_smoothed_per_thousand          84
# positive_rate                            84
# tests_per_case                           84
# tests_units                              77
# stringency_index                         9
# female_smokers                           315
# male_smokers                             315

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')


#df.columns

df.shape
# .dropna() vs. . dropna(how='all')

# 6) Show the result after droping rows 
#which have at least one NaN data in the dataset ()  (2 pts)
cleaned = df.dropna()

print('After using .dropn(), total records: ')
print(len(cleaned))
# Out:
# Sakina Fathima Khan , id: kh20830 6537
# ------------------------------
# After using .dropn(), total records:
# 0

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

# 7) Show the result after after droping rows which all data is NaN in the dataset ()  (2 pts)

cleaned = df.dropna(how='all')

print("After using .dropna(how='all'), total records:")
print(len(cleaned))
# Out:
# Sakina Fathima Khan , id: kh20830 7843
# ------------------------------
# After using .dropna(how='all'), total records:
# 59973

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

print(df.shape)
print('Original row number:', len(df))

# 8) Show the result after dropping the rows which continent or iso data is missing in the dataset
#    How many rows are dropped. (2 pts)
cleaned_data = df[df.continent.notnull() & df.iso_code.notnull()]
bad_data = df[df.continent.isnull() | df.iso_code.isnull()]
print("After droping all missing data of continent or iso in the dataset")
print('New dataset included record number:', len(cleaned_data))
print('The number of rows dropped: ', len(bad_data))
# Out:
# Sakina Fathima Khan , id: kh20830 7926
# ------------------------------
# (59973, 50)
# Original row number: 59973
# After droping all missing data of continent or iso in the dataset
# New dataset included record number: 59658
# The number of rows dropped:  315

# %%
res = df[df['location']=='Iraq']
res[['location','handwashing_facilities']]
# Out:
#       location  handwashing_facilities
# 24956     Iraq                  94.576
# 24957     Iraq                  94.576
# ...        ...                     ...
# 25269     Iraq                  94.576
# 25270     Iraq                  94.576
#
# [315 rows x 2 columns]

# %%
# 9) Show Iraq's handwashing_facilities information
#    Show the average of handwashing_facilities of worldwide level

import random
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

#print(df['handwashing_facilities'].describe())
print("Before handwashing_facilities values are missing in Iraq")
res = df[df['location']=='Iraq']
print(len(res))
data = res[res['handwashing_facilities'].notnull()] [['location', 'date', 'handwashing_facilities']]
print(data)

print('---------------------------------------------------------------------------------------------------------')

#for Iraq, replace handwashing_facilities value as average of worldiwde level
avg = df['handwashing_facilities'].mean()
print('The avergae of handwashing_facilities of worldwide:', format(avg, '.2f'))
# Out:
# Sakina Fathima Khan , id: kh20830 1254
# ------------------------------
# Before handwashing_facilities values are missing in Iraq
# 315
#       location        date  handwashing_facilities
# 24956     Iraq  2020-01-23                  94.576
# 24957     Iraq  2020-01-24                  94.576
# ...        ...         ...                     ...
# 25269     Iraq  2020-12-01                  94.576
# 25270     Iraq  2020-12-02                  94.576
#
# [315 rows x 3 columns]
# ---------------------------------------------------------------------------------------------------------
# The avergae of handwashing_facilities of worldwide: 50.22

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

import math

# 10) Replace handwashing_facilities in Brazil as the average of worldwide level (2 pts)
res = df[df['location']=='Iraq']
avg = df['handwashing_facilities'].mean()
avg = math.floor(avg)

print("Now handwashing_facilities values are replace by the average of worldwide level")
data

res['handwashing_facilities'].fillna(avg, inplace=True )
res[['location', 'date', 'handwashing_facilities']]
# Out:
# Sakina Fathima Khan , id: kh20830 314
# ------------------------------
# Now handwashing_facilities values are replace by the average of worldwide level
# C:\Users\sakin\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#       location        date  handwashing_facilities
# 24956     Iraq  2020-01-23                  94.576
# 24957     Iraq  2020-01-24                  94.576
# ...        ...         ...                     ...
# 25269     Iraq  2020-12-01                  94.576
# 25270     Iraq  2020-12-02                  94.576
#
# [315 rows x 3 columns]

# %% [markdown]
# # D) Sorting, Grouping and plotting
# # ( 30 pts)
#
# ## df.sort_values(by=['a','b'], ascending = True)
# ### df.sort_index()
# ### df.groupby( )

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')
import matplotlib.pyplot as plt

# 1)  (3 pts) Find the top 10 countries which have the most covid cases

# Group all cases by location , become series
cases = df.groupby(df.location).new_cases.sum()
cases = cases.sort_values(ascending = False)
cases
res = cases.head(10)
countries = res.index

print('10 countries which have the most covid cases')
print('Country              covid cases')
print('--------------------------------------------------')
for country in countries:
    print('{0: <20}' . format(country), '\t', format(res[country], '.0f'))
# Out:
# Sakina Fathima Khan , id: kh20830 1805
# ------------------------------
# 10 countries which have the most covid cases
# Country              covid cases
# --------------------------------------------------
# United States        	 13921373
# India                	 9534964
# Brazil               	 6436650
# Russia               	 2327105
# France               	 2297393
# Spain                	 1665775
# United Kingdom       	 1663467
# Italy                	 1641610
# Argentina            	 1440103
# Colombia             	 1334089

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')


# 2) Use bar chart to show the top 10 countries which have the most covid cases. (3 pts)
res = cases.head(10)
res
res = cases.head(10)
print(res.index)
print(res.values)
res.plot(kind = 'bar', title = '10 countries which have the most covid cases')
# Out:
# Sakina Fathima Khan , id: kh20830 6802
# ------------------------------
# Index(['United States', 'India', 'Brazil', 'Russia', 'France', 'Spain',
#        'United Kingdom', 'Italy', 'Argentina', 'Colombia'],
#       dtype='object', name='location')
# [13921373.  9534964.  6436650.  2327105.  2297393.  1665775.  1663467.
#   1641610.  1440103.  1334089.]

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

# (3  pts)

# 3) Show worldwide, which ten day has the most new cases? 

#    Use line chart to show the top 10 days which have the most new covid cases 

#group all cases by location, become series
cases = df.groupby(df.date).new_cases.sum()
cases = cases.sort_values(ascending = False)

res = cases.head(10)
res = res.sort_index()
days = res.index

print('Ten days which have the most covid cases')
print('Date               covid cases')
print('------------------------------------------')
for day in days:
    print(day, '\t', format(res[day], '.0f'))

# Draw bar chart
plt.title("Top ten days which have the most covid cases")
plt.xlabel("Date")
plt.ylabel("Numbers")

plt.plot(res.index,res.values, color ='b')
res.plot(kind = 'line', rot = 45, linestyle = 'dashed', marker='o')
# Out:
# Sakina Fathima Khan , id: kh20830 3807
# ------------------------------
# Ten days which have the most covid cases
# Date               covid cases
# ------------------------------------------
# 2020-11-06 	 642162
# 2020-11-11 	 645209
# 2020-11-12 	 647434
# 2020-11-13 	 648898
# 2020-11-18 	 623958
# 2020-11-19 	 650645
# 2020-11-20 	 666275
# 2020-11-25 	 633149
# 2020-11-27 	 672046
# 2020-12-02 	 646521

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

# (3  pts)

# 4) On 2020-11-30, which ten countries has the most new cases? 

#    Use bar chart to show the top 10 location which have the most new covid cases 

df1 = df[df.date == '2020-11-30']

#group
cases = df1.sort_values(by = 'new_cases', ascending = False)

res = cases.head(10)[['location', 'new_cases']]
res1 = res.sort_index()
#print(res)

# Display dataframe
print('On 2020-11-30')
print('10 countries which have the most covid cases on 2020-11-30')
print('country                covid cases')
print('----------------------------------------------------------------')
for i in range(len(res)):
    country = res['location'].iloc[i]
    new_cases = res['new_cases'].iloc[i]
    print('{0: <20}'.format(country), '\t', format(new_cases, '.0f'))
    
#Draw bar chart
plt.title('10 countries which have the most covid cases in 2020-11-30')
plt.xlabel("Date")
plt.ylabel("Numbers")

plt.bar(res['location'],res['new_cases'], color = 'b')
# Out:
# Sakina Fathima Khan , id: kh20830 1831
# ------------------------------
# On 2020-11-30
# 10 countries which have the most covid cases on 2020-11-30
# country                covid cases
# ----------------------------------------------------------------
# United States        	 157901
# Turkey               	 31219
# India                	 31118
# Russia               	 26046
# Brazil               	 21138
# Spain                	 19979
# Italy                	 16376
# Germany              	 14221
# Iran                 	 13321
# United Kingdom       	 12428
# <BarContainer object of 10 artists>

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

# (3  pts)


#  5)  Show last seven days, the new cases in Brazil/US/India/Russia (Chose one country),
#      Plot a line chart
cases = df[df.location == 'Iraq'].sort_values(by = 'date', ascending = True)
cases
res = cases[['date', 'new_cases' ]].tail(7)

print('\nIn the past seven days the new cases in Iraq')
print('Date                       covid cases')
print('------------------------------------------------')
dates = res['date']
for i in res.index:
    print(res['date'][i], '\t', format(res['new_cases'][i], '.0f'))
    
plt.title("new covid cases in past 10 days in Iraq")
plt.xlabel("Date")
plt.ylabel("Numbers")

plt.plot(res['date'], res['new_cases'], color = 'b')
# Out:
# Sakina Fathima Khan , id: kh20830 7333
# ------------------------------
#
# In the past seven days the new cases in Iraq
# Date                       covid cases
# ------------------------------------------------
# 2020-11-26 	 2483
# 2020-11-27 	 2545
# 2020-11-28 	 1606
# 2020-11-29 	 1614
# 2020-11-30 	 2114
# 2020-12-01 	 2218
# 2020-12-02 	 1961

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')


# 6-7) Group by contient, show total of new covid cases for each contient and sorted by total number
#    Plot the result by pie chart (3 pts)
df
res = df.groupby(df.continent).new_cases.sum().sort_values(ascending = False)

print('Total covid new cases by continent')
print('------------------------------------------')
names = res.index
for name in names:
    print('{0: <20}'.format(name), '\t', format(res[name], '.0f'))

res.plot(kind ='pie', title = 'Covid new cases of percentages by continent', autopct ='%1.1f%%')
# Out:
# Sakina Fathima Khan , id: kh20830 8936
# ------------------------------
# Total covid new cases by continent
# ------------------------------------------
# Europe               	 17751436
# Asia                 	 17040786
# North America        	 16231591
# South America        	 11272758
# Africa               	 2201303
# Oceania              	 30741

# %%
res
# Out:
# continent
# Europe     17751436.0
# Asia       17040786.0
#               ...
# Africa      2201303.0
# Oceania       30741.0
# Name: new_cases, Length: 6, dtype: float64

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

# 8) Show the top 10 countries which have the most population  (3 pts)
df
res = df[df.date == '2020-11-30'][['location', 'population']].sort_values(by='population', ascending = False)
res = res.head(10)
res.index

print('Top 10 countries which have the most POPULATIOn')
for i in res.index:
    print('{0: <20}'.format(res['location'][i]), format(res['population'][i], '.0f'))
    
res2 = res.set_index('location')

res2.plot(kind='bar', title = 'Top 10 countries which have the most population')
# Out:
# Sakina Fathima Khan , id: kh20830 9401
# ------------------------------
# Top 10 countries which have the most POPULATIOn
# China                1439323774
# India                1380004385
# United States        331002647
# Indonesia            273523621
# Pakistan             220892331
# Brazil               212559409
# Nigeria              206139587
# Bangladesh           164689383
# Russia               145934460
# Mexico               128932753

# %%
number = random.randint(0,10000)
print("Sakina Fathima Khan , id: kh20830", number )
print('------------------------------')

# 9-10) Show the world poplation
#      Show the  population by each continent and show it as pie chart (6 pts)
data = df[df.date=='2020-11-30']
pop_sum = data['population'].sum()
print('the world population', pop_sum)

data = df[df.date=='2020-11-30'][['continent', 'location', 'date', 'population']]

res = df.groupby([df.continent]).population.sum().sort_values(ascending = False)

print('population by continent')
print('--------------------------------')
names = res.index
for name in names:
    print('{0: <20}'.format(name), '\t', format(res[name], '.0f'))

res.plot(kind = 'pie', title = 'Covid new cases of percentages by continent', autopct = '%1.1f%%')
# Out:
# Sakina Fathima Khan , id: kh20830 2376
# ------------------------------
# the world population 7746825445.0
# population by continent
# --------------------------------
# Asia                 	 1452651739060
# Africa               	 421918535115
# Europe               	 235673706555
# North America        	 188281532013
# South America        	 135594146205
# Oceania              	 12983924205
